# %%
import apache_beam as beam
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner
import apache_beam.runners.interactive.interactive_beam as ib
from apache_beam.options import pipeline_options
from apache_beam.options.pipeline_options import GoogleCloudOptions, PipelineOptions
from apache_beam.io.gcp.bigquery import BigQueryDisposition, WriteToBigQuery
from apache_beam.io.gcp.pubsub import ReadFromPubSub
from apache_beam.runners import DataflowRunner
import google.auth
import json

# %%
options = pipeline_options.PipelineOptions()

options.view_as(pipeline_options.StandardOptions).streaming = True

p = beam.Pipeline(options=options)

# %%
messages = (p | "read" >> beam.io.ReadFromPubSub(topic="projects/our-shield-373717/topics/collect-data")
              | "print" >> beam.Map(print))
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-bca978b5-584c-42d7-9d03-60256f50090b.json']

# %%
p.run()

# %% [markdown]
# #### Apache Beam - Dataflow runner

# %%
import apache_beam as beam
from apache_beam.runners import DataflowRunner
from apache_beam.options import pipeline_options
from apache_beam.options.pipeline_options import GoogleCloudOptions
import google.auth

# %%
options = pipeline_options.PipelineOptions()

# Set the project to the default project in your current Google Cloud
# environment.
_, options.view_as(GoogleCloudOptions).project = google.auth.default()

# Choose a Cloud Storage location.
dataflow_gcs_location = 'gs://another_bucket_pubsub/dataflow'

# Set the staging location. This location is used to stage the
# Dataflow pipeline and SDK binary.
options.view_as(GoogleCloudOptions).staging_location = '%s/staging' % dataflow_gcs_location

# Set the temporary location. This location is used to store temporary files
# or intermediate results before outputting to the sink.
options.view_as(GoogleCloudOptions).temp_location = '%s/temp' % dataflow_gcs_location

##### Required for Pub/Sub : set the streaming option #####
options.view_as(pipeline_options.StandardOptions).streaming = True

p = beam.Pipeline(options=options)

# %%
table_spec = 'our-shield-373717:our-shield-373717.dataset_order.string_table'
table_schema = 'test_values: STRING'

# %%
class TextToDict(beam.DoFn):
    def process(self, element):
        print(element)
        print("message: {}".format(element))
        diction = {'test_values': element}
        yield diction

# %%
messages = (p | "read" >> beam.io.ReadFromPubSub(topic="projects/our-shield-373717/topics/collect-data")
              | "encode in dict" >> beam.ParDo(TextToDict())
              | "print" >> beam.Map(print))
# Out:
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['-f', '/root/.local/share/jupyter/runtime/kernel-bca978b5-584c-42d7-9d03-60256f50090b.json']

# %%
messages | beam.io.WriteToBigQuery(table_spec, schema = table_schema, write_disposition=beam.io.BigQueryDisposition.WRITE_APPEND, create_disposition=beam.io.BigQueryDisposition.CREATE_IF_NEEDED)

# %% [markdown]
# #### Pipeline complète fonctionnelle

# %%
project = google.auth.default()[1]
project
# Out:
# 'our-shield-373717'

# %%
topic = "projects/{}/topics/collect-data".format(project)
table = "{}:dataset_order.order_table".format(project)
schema = "customer_id:integer,order_id:integer,order_amount:float"
bucket = "gs://spark_bucket_rbgt"
region="us-east1"

options = PipelineOptions(
    flags={},
    streaming=True,
    project=project,
    region=region,
    staging_location="%s/staging" % bucket,
    temp_location="%s/temp" % bucket
)

p = beam.Pipeline(DataflowRunner(), options=options)

elements = (p | "Read Topic" >> ReadFromPubSub(topic=topic)
              | "To Dict" >> beam.Map(json.loads)) # Example message: {"name": "carlos", 'score': 10, 'timestamp': "2020-03-14 17:29:00.00000"}

elements | "Write To BigQuery" >> WriteToBigQuery(table=table, schema=schema,
                              create_disposition=BigQueryDisposition.CREATE_IF_NEEDED,
                              write_disposition=BigQueryDisposition.WRITE_APPEND)

pipeline = p.run()
# Out:
#   <style>
#     div.alert {
#       white-space: pre-line;
#     }
#   </style>
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div class="alert alert-info">No cache_root detected. Defaulting to staging_location gs://spark_bucket_rbgt/staging for cache location.</div>
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
# b'{"customer_id": 41.0, "order_id": 7766.0, "order_amount": 67.66}'
# b'{"customer_id": 28.0, "order_id": 2239.0, "order_amount": 19.92}'
# b'{"customer_id": 74.0, "order_id": 9053.0, "order_amount": 64.47}'
# b'{"customer_id": 84.0, "order_id": 5460.0, "order_amount": 47.38}'
# b'{"customer_id": 5.0, "order_id": 2441.0, "order_amount": 88.12}'
# b'{"customer_id": 33.0, "order_id": 4759.0, "order_amount": 89.42}'
# b'{"customer_id": 8.0, "order_id": 6873.0, "order_amount": 38.29}'
# b'{"customer_id": 23.0, "order_id": 7702.0, "order_amount": 20.4}'
# b'{"customer_id": 60.0, "order_id": 1261.0, "order_amount": 24.44}'
# b'{"customer_id": 36.0, "order_id": 3321.0, "order_amount": 66.97}'
# b'{"customer_id": 57.0, "order_id": 199.0, "order_amount": 0.94}'
# b'{"customer_id": 31.0, "order_id": 8219.0, "order_amount": 25.48}'
# b'{"customer_id": 27.0, "order_id": 5312.0, "order_amount": 24.34}'
# b'{"customer_id": 25.0, "order_id": 4657.0, "order_amount": 8.23}'
# b'{"customer_id": 4.0, "order_id": 2218.0, "order_amount": 42.68}'
# b'{"customer_id": 73.0, "order_id": 7661.0, "order_amount": 56.31}'
# b'{"customer_id": 56.0, "order_id": 683.0, "order_amount": 33.83}'
# b'{"customer_id": 34.0, "order_id": 1341.0, "order_amount": 81.2}'
# b'{"customer_id": 82.0, "order_id": 9008.0, "order_amount": 53.62}'
# b'{"customer_id": 57.0, "order_id": 7971.0, "order_amount": 86.07}'
# b'{"customer_id": 98.0, "order_id": 1915.0, "order_amount": 92.03}'
# b'{"customer_id": 58.0, "order_id": 2194.0, "order_amount": 17.73}'
# b'{"customer_id": 54.0, "order_id": 1179.0, "order_amount": 2.32}'
# b'{"customer_id": 68.0, "order_id": 9693.0, "order_amount": 43.43}'
# b'{"customer_id": 17.0, "order_id": 8706.0, "order_amount": 68.54}'
# b'{"customer_id": 34.0, "order_id": 3816.0, "order_amount": 69.98}'
# b'{"customer_id": 33.0, "order_id": 8517.0, "order_amount": 30.43}'
# b'{"customer_id": 18.0, "order_id": 4584.0, "order_amount": 2.44}'
# b'{"customer_id": 89.0, "order_id": 4345.0, "order_amount": 16.82}'
# b'{"customer_id": 51.0, "order_id": 6267.0, "order_amount": 39.64}'
# b'{"customer_id": 31.0, "order_id": 8350.0, "order_amount": 53.14}'
# b'{"customer_id": 17.0, "order_id": 7158.0, "order_amount": 42.08}'
# b'{"customer_id": 41.0, "order_id": 1371.0, "order_amount": 34.06}'
# b'{"customer_id": 69.0, "order_id": 2762.0, "order_amount": 14.08}'
# b'{"customer_id": 39.0, "order_id": 4699.0, "order_amount": 64.82}'
# b'{"customer_id": 10.0, "order_id": 2476.0, "order_amount": 12.44}'
# b'{"customer_id": 4.0, "order_id": 9107.0, "order_amount": 75.2}'
# b'{"customer_id": 45.0, "order_id": 5182.0, "order_amount": 11.26}'
# b'{"customer_id": 67.0, "order_id": 9276.0, "order_amount": 79.6}'
# b'{"customer_id": 70.0, "order_id": 2987.0, "order_amount": 99.13}'
# b'{"customer_id": 22.0, "order_id": 62.0, "order_amount": 39.22}'
# b'{"customer_id": 4.0, "order_id": 5640.0, "order_amount": 84.57}'
# b'{"customer_id": 18.0, "order_id": 9105.0, "order_amount": 51.04}'
# b'{"customer_id": 59.0, "order_id": 1666.0, "order_amount": 73.5}'
# b'{"customer_id": 65.0, "order_id": 7083.0, "order_amount": 23.42}'
# b'{"customer_id": 18.0, "order_id": 6524.0, "order_amount": 18.23}'
# b'{"customer_id": 71.0, "order_id": 2461.0, "order_amount": 53.53}'
# b'{"customer_id": 74.0, "order_id": 12.0, "order_amount": 23.42}'
# b'{"customer_id": 34.0, "order_id": 1522.0, "order_amount": 47.44}'
# b'{"customer_id": 30.0, "order_id": 160.0, "order_amount": 33.14}'
# b'{"customer_id": 16.0, "order_id": 424.0, "order_amount": 90.22}'
# b'{"customer_id": 53.0, "order_id": 6207.0, "order_amount": 25.94}'
# b'{"customer_id": 85.0, "order_id": 3598.0, "order_amount": 35.96}'
# b'{"customer_id": 60.0, "order_id": 6446.0, "order_amount": 61.15}'
# b'{"customer_id": 86.0, "order_id": 4082.0, "order_amount": 54.77}'
# b'{"customer_id": 23.0, "order_id": 2308.0, "order_amount": 27.06}'
# b'{"customer_id": 91.0, "order_id": 5831.0, "order_amount": 53.13}'
# b'{"customer_id": 86.0, "order_id": 795.0, "order_amount": 79.84}'
# b'{"customer_id": 79.0, "order_id": 8200.0, "order_amount": 74.86}'
# b'{"customer_id": 56.0, "order_id": 5672.0, "order_amount": 64.92}'
# b'{"customer_id": 57.0, "order_id": 3811.0, "order_amount": 82.78}'
# b'{"customer_id": 90.0, "order_id": 2324.0, "order_amount": 87.23}'
# b'{"customer_id": 90.0, "order_id": 7298.0, "order_amount": 11.4}'
# b'{"customer_id": 36.0, "order_id": 6328.0, "order_amount": 91.92}'
# b'{"customer_id": 85.0, "order_id": 1051.0, "order_amount": 23.58}'
# b'{"customer_id": 55.0, "order_id": 4657.0, "order_amount": 39.41}'
# b'{"customer_id": 44.0, "order_id": 1919.0, "order_amount": 39.54}'
# b'{"customer_id": 68.0, "order_id": 8983.0, "order_amount": 28.62}'
# b'{"customer_id": 11.0, "order_id": 8220.0, "order_amount": 92.23}'
# b'{"customer_id": 95.0, "order_id": 1140.0, "order_amount": 50.72}'
# b'{"customer_id": 65.0, "order_id": 5129.0, "order_amount": 11.76}'
# b'{"customer_id": 86.0, "order_id": 6442.0, "order_amount": 11.01}'
# b'{"customer_id": 73.0, "order_id": 6217.0, "order_amount": 58.84}'
# b'{"customer_id": 57.0, "order_id": 4760.0, "order_amount": 37.47}'
# b'{"customer_id": 49.0, "order_id": 1496.0, "order_amount": 65.19}'
# b'{"customer_id": 10.0, "order_id": 987.0, "order_amount": 74.45}'
# b'{"customer_id": 16.0, "order_id": 1415.0, "order_amount": 15.7}'
# b'{"customer_id": 46.0, "order_id": 7497.0, "order_amount": 35.18}'
# b'{"customer_id": 41.0, "order_id": 9727.0, "order_amount": 64.25}'
# b'{"customer_id": 14.0, "order_id": 5998.0, "order_amount": 80.53}'
# b'{"customer_id": 15.0, "order_id": 5062.0, "order_amount": 56.94}'
# b'{"customer_id": 58.0, "order_id": 8742.0, "order_amount": 1.88}'
# b'{"customer_id": 65.0, "order_id": 558.0, "order_amount": 33.84}'
# b'{"customer_id": 37.0, "order_id": 2066.0, "order_amount": 23.4}'
# b'{"customer_id": 75.0, "order_id": 8818.0, "order_amount": 3.52}'
# b'{"customer_id": 21.0, "order_id": 606.0, "order_amount": 46.11}'
# b'{"customer_id": 87.0, "order_id": 4954.0, "order_amount": 53.49}'
# b'{"customer_id": 50.0, "order_id": 7185.0, "order_amount": 13.62}'
# b'{"customer_id": 47.0, "order_id": 1304.0, "order_amount": 22.81}'
# b'{"customer_id": 47.0, "order_id": 5544.0, "order_amount": 45.38}'
# b'{"customer_id": 64.0, "order_id": 9648.0, "order_amount": 49.7}'
# b'{"customer_id": 17.0, "order_id": 3698.0, "order_amount": 91.68}'
# b'{"customer_id": 60.0, "order_id": 2870.0, "order_amount": 31.85}'
# b'{"customer_id": 10.0, "order_id": 3471.0, "order_amount": 68.65}'
# b'{"customer_id": 2.0, "order_id": 9150.0, "order_amount": 76.88}'
# b'{"customer_id": 98.0, "order_id": 4126.0, "order_amount": 54.39}'
# b'{"customer_id": 7.0, "order_id": 3530.0, "order_amount": 51.38}'
# b'{"customer_id": 33.0, "order_id": 6721.0, "order_amount": 10.8}'
# b'{"customer_id": 62.0, "order_id": 5982.0, "order_amount": 41.77}'
# b'{"customer_id": 15.0, "order_id": 5033.0, "order_amount": 88.82}'
# b'{"customer_id": 46.0, "order_id": 1183.0, "order_amount": 10.78}'
# b'{"customer_id": 22.0, "order_id": 6885.0, "order_amount": 66.88}'
# b'{"customer_id": 42.0, "order_id": 3691.0, "order_amount": 42.23}'
# b'{"customer_id": 92.0, "order_id": 8915.0, "order_amount": 45.56}'
# b'{"customer_id": 41.0, "order_id": 5984.0, "order_amount": 78.67}'
# b'{"customer_id": 18.0, "order_id": 7180.0, "order_amount": 83.23}'
# b'{"customer_id": 37.0, "order_id": 2134.0, "order_amount": 60.01}'
# b'{"customer_id": 10.0, "order_id": 8643.0, "order_amount": 89.53}'
# b'{"customer_id": 76.0, "order_id": 1062.0, "order_amount": 80.24}'
# b'{"customer_id": 35.0, "order_id": 9477.0, "order_amount": 27.8}'
# b'{"customer_id": 64.0, "order_id": 9330.0, "order_amount": 19.94}'
# b'{"customer_id": 6.0, "order_id": 4873.0, "order_amount": 44.47}'
# b'{"customer_id": 73.0, "order_id": 7623.0, "order_amount": 39.3}'
# b'{"customer_id": 99.0, "order_id": 6566.0, "order_amount": 74.37}'
# b'{"customer_id": 25.0, "order_id": 8888.0, "order_amount": 2.01}'
# b'{"customer_id": 64.0, "order_id": 3715.0, "order_amount": 89.15}'
# b'{"customer_id": 73.0, "order_id": 5161.0, "order_amount": 22.41}'
# b'{"customer_id": 58.0, "order_id": 4014.0, "order_amount": 24.83}'
# b'{"customer_id": 99.0, "order_id": 1670.0, "order_amount": 28.9}'
# b'{"customer_id": 0.0, "order_id": 1593.0, "order_amount": 59.8}'
# b'{"customer_id": 82.0, "order_id": 2069.0, "order_amount": 47.48}'
# b'{"customer_id": 66.0, "order_id": 8021.0, "order_amount": 51.27}'
# b'{"customer_id": 43.0, "order_id": 1087.0, "order_amount": 92.08}'
# b'{"customer_id": 23.0, "order_id": 3429.0, "order_amount": 62.31}'
# b'{"customer_id": 22.0, "order_id": 200.0, "order_amount": 22.82}'
# b'{"customer_id": 80.0, "order_id": 8532.0, "order_amount": 47.71}'
# b'{"customer_id": 92.0, "order_id": 941.0, "order_amount": 20.43}'
# b'{"customer_id": 34.0, "order_id": 4257.0, "order_amount": 33.83}'
# b'{"customer_id": 56.0, "order_id": 7493.0, "order_amount": 31.61}'
# b'{"customer_id": 30.0, "order_id": 794.0, "order_amount": 25.51}'
# b'{"customer_id": 53.0, "order_id": 2686.0, "order_amount": 47.8}'
# b'{"customer_id": 2.0, "order_id": 4326.0, "order_amount": 10.46}'
# b'{"customer_id": 69.0, "order_id": 3008.0, "order_amount": 33.77}'
# b'{"customer_id": 78.0, "order_id": 4462.0, "order_amount": 47.04}'
# b'{"customer_id": 29.0, "order_id": 8324.0, "order_amount": 50.12}'
# b'{"customer_id": 62.0, "order_id": 8175.0, "order_amount": 79.67}'
# b'{"customer_id": 52.0, "order_id": 9639.0, "order_amount": 45.35}'
# b'{"customer_id": 80.0, "order_id": 5780.0, "order_amount": 16.18}'
# b'{"customer_id": 99.0, "order_id": 9301.0, "order_amount": 32.85}'
# b'{"customer_id": 49.0, "order_id": 9059.0, "order_amount": 21.27}'
# b'{"customer_id": 72.0, "order_id": 5768.0, "order_amount": 58.0}'
# b'{"customer_id": 66.0, "order_id": 5709.0, "order_amount": 41.87}'
# b'{"customer_id": 1.0, "order_id": 9244.0, "order_amount": 50.82}'
# b'{"customer_id": 25.0, "order_id": 3889.0, "order_amount": 99.16}'
# b'{"customer_id": 63.0, "order_id": 3530.0, "order_amount": 83.52}'
# b'{"customer_id": 12.0, "order_id": 2932.0, "order_amount": 1.02}'
# b'{"customer_id": 17.0, "order_id": 3496.0, "order_amount": 68.6}'
# b'{"customer_id": 67.0, "order_id": 4046.0, "order_amount": 41.73}'
# b'{"customer_id": 24.0, "order_id": 3987.0, "order_amount": 57.9}'
# b'{"customer_id": 72.0, "order_id": 5415.0, "order_amount": 82.9}'
# b'{"customer_id": 43.0, "order_id": 4695.0, "order_amount": 27.8}'
# b'{"customer_id": 1.0, "order_id": 5562.0, "order_amount": 15.32}'
# b'{"customer_id": 76.0, "order_id": 8032.0, "order_amount": 97.91}'
# b'{"customer_id": 11.0, "order_id": 548.0, "order_amount": 93.5}'
# b'{"customer_id": 64.0, "order_id": 7215.0, "order_amount": 72.96}'
# b'{"customer_id": 93.0, "order_id": 993.0, "order_amount": 79.03}'
# b'{"customer_id": 12.0, "order_id": 594.0, "order_amount": 87.66}'
# b'{"customer_id": 57.0, "order_id": 8953.0, "order_amount": 24.41}'
# b'{"customer_id": 26.0, "order_id": 5083.0, "order_amount": 21.53}'
# b'{"customer_id": 73.0, "order_id": 5108.0, "order_amount": 67.18}'
# b'{"customer_id": 50.0, "order_id": 3600.0, "order_amount": 5.7}'
# b'{"customer_id": 9.0, "order_id": 5768.0, "order_amount": 45.04}'
# b'{"customer_id": 34.0, "order_id": 7860.0, "order_amount": 23.47}'
# b'{"customer_id": 51.0, "order_id": 6112.0, "order_amount": 45.51}'
# b'{"customer_id": 54.0, "order_id": 183.0, "order_amount": 26.98}'
# b'{"customer_id": 36.0, "order_id": 9874.0, "order_amount": 3.81}'
# b'{"customer_id": 77.0, "order_id": 3103.0, "order_amount": 72.17}'
# b'{"customer_id": 55.0, "order_id": 6067.0, "order_amount": 47.05}'
# b'{"customer_id": 42.0, "order_id": 6289.0, "order_amount": 82.45}'
# b'{"customer_id": 1.0, "order_id": 1334.0, "order_amount": 89.68}'
# b'{"customer_id": 2.0, "order_id": 6161.0, "order_amount": 23.71}'
# b'{"customer_id": 98.0, "order_id": 965.0, "order_amount": 71.58}'
# b'{"customer_id": 62.0, "order_id": 7798.0, "order_amount": 83.89}'
# b'{"customer_id": 14.0, "order_id": 2389.0, "order_amount": 23.79}'
# b'{"customer_id": 40.0, "order_id": 5553.0, "order_amount": 2.96}'
# b'{"customer_id": 64.0, "order_id": 1521.0, "order_amount": 90.44}'
# b'{"customer_id": 46.0, "order_id": 7755.0, "order_amount": 88.09}'
# b'{"customer_id": 55.0, "order_id": 9368.0, "order_amount": 69.93}'
# b'{"customer_id": 26.0, "order_id": 7312.0, "order_amount": 12.79}'
# b'{"customer_id": 14.0, "order_id": 2015.0, "order_amount": 11.78}'
# b'{"customer_id": 21.0, "order_id": 6309.0, "order_amount": 96.6}'
# b'{"customer_id": 97.0, "order_id": 642.0, "order_amount": 37.78}'
# b'{"customer_id": 13.0, "order_id": 6380.0, "order_amount": 16.0}'
# b'{"customer_id": 96.0, "order_id": 5863.0, "order_amount": 99.84}'
# b'{"customer_id": 2.0, "order_id": 3729.0, "order_amount": 15.44}'
# b'{"customer_id": 22.0, "order_id": 4129.0, "order_amount": 41.49}'
# b'{"customer_id": 34.0, "order_id": 4323.0, "order_amount": 7.84}'
# b'{"customer_id": 47.0, "order_id": 5215.0, "order_amount": 50.69}'
# b'{"customer_id": 37.0, "order_id": 7173.0, "order_amount": 61.99}'
# b'{"customer_id": 99.0, "order_id": 7631.0, "order_amount": 87.87}'
# b'{"customer_id": 68.0, "order_id": 3876.0, "order_amount": 25.16}'
# b'{"customer_id": 15.0, "order_id": 8875.0, "order_amount": 2.1}'
# b'{"customer_id": 65.0, "order_id": 8874.0, "order_amount": 94.2}'
# b'{"customer_id": 99.0, "order_id": 9332.0, "order_amount": 72.35}'
# b'{"customer_id": 12.0, "order_id": 4639.0, "order_amount": 15.02}'
# b'{"customer_id": 38.0, "order_id": 6474.0, "order_amount": 44.21}'
# b'{"customer_id": 77.0, "order_id": 6158.0, "order_amount": 80.5}'
# b'{"customer_id": 38.0, "order_id": 2780.0, "order_amount": 42.86}'
# b'{"customer_id": 21.0, "order_id": 7466.0, "order_amount": 59.96}'
# b'{"customer_id": 29.0, "order_id": 3544.0, "order_amount": 34.75}'
# b'{"customer_id": 1.0, "order_id": 161.0, "order_amount": 36.77}'
# b'{"customer_id": 41.0, "order_id": 8217.0, "order_amount": 51.97}'
# b'{"customer_id": 25.0, "order_id": 7950.0, "order_amount": 59.67}'
# b'{"customer_id": 5.0, "order_id": 1301.0, "order_amount": 59.27}'
# b'{"customer_id": 92.0, "order_id": 5316.0, "order_amount": 48.39}'
# b'{"customer_id": 43.0, "order_id": 5421.0, "order_amount": 69.28}'
# b'{"customer_id": 23.0, "order_id": 6583.0, "order_amount": 42.74}'
# b'{"customer_id": 87.0, "order_id": 8111.0, "order_amount": 44.46}'
# b'{"customer_id": 93.0, "order_id": 69.0, "order_amount": 32.57}'
# b'{"customer_id": 78.0, "order_id": 5037.0, "order_amount": 94.49}'
# b'{"customer_id": 3.0, "order_id": 6372.0, "order_amount": 82.04}'
# b'{"customer_id": 73.0, "order_id": 1678.0, "order_amount": 35.38}'
# b'{"customer_id": 77.0, "order_id": 411.0, "order_amount": 72.73}'
# b'{"customer_id": 63.0, "order_id": 3511.0, "order_amount": 91.51}'
# b'{"customer_id": 29.0, "order_id": 3511.0, "order_amount": 71.41}'
# b'{"customer_id": 88.0, "order_id": 3896.0, "order_amount": 2.63}'
# b'{"customer_id": 72.0, "order_id": 6539.0, "order_amount": 69.01}'
# b'{"customer_id": 84.0, "order_id": 4534.0, "order_amount": 34.23}'
# b'{"customer_id": 13.0, "order_id": 105.0, "order_amount": 73.7}'
# b'{"customer_id": 67.0, "order_id": 3866.0, "order_amount": 97.99}'
# b'{"customer_id": 7.0, "order_id": 1644.0, "order_amount": 8.79}'
# b'{"customer_id": 29.0, "order_id": 8910.0, "order_amount": 32.69}'
# b'{"customer_id": 29.0, "order_id": 207.0, "order_amount": 79.43}'
# b'{"customer_id": 11.0, "order_id": 6564.0, "order_amount": 15.24}'
# b'{"customer_id": 83.0, "order_id": 4285.0, "order_amount": 10.4}'
# b'{"customer_id": 29.0, "order_id": 3302.0, "order_amount": 71.61}'
# b'{"customer_id": 90.0, "order_id": 3465.0, "order_amount": 78.04}'
# b'{"customer_id": 3.0, "order_id": 94.0, "order_amount": 92.1}'
# b'{"customer_id": 10.0, "order_id": 7662.0, "order_amount": 46.16}'
# b'{"customer_id": 98.0, "order_id": 3886.0, "order_amount": 65.35}'
# b'{"customer_id": 64.0, "order_id": 2860.0, "order_amount": 69.77}'
# b'{"customer_id": 56.0, "order_id": 747.0, "order_amount": 13.16}'
# b'{"customer_id": 94.0, "order_id": 9175.0, "order_amount": 57.78}'
# b'{"customer_id": 11.0, "order_id": 458.0, "order_amount": 8.24}'
# b'{"customer_id": 70.0, "order_id": 9727.0, "order_amount": 12.24}'
# b'{"customer_id": 54.0, "order_id": 826.0, "order_amount": 58.9}'
# b'{"customer_id": 68.0, "order_id": 1848.0, "order_amount": 97.01}'
# b'{"customer_id": 70.0, "order_id": 1782.0, "order_amount": 49.38}'
# b'{"customer_id": 17.0, "order_id": 6060.0, "order_amount": 43.3}'
# b'{"customer_id": 14.0, "order_id": 6891.0, "order_amount": 26.94}'
# b'{"customer_id": 11.0, "order_id": 4298.0, "order_amount": 18.74}'
# b'{"customer_id": 92.0, "order_id": 9073.0, "order_amount": 59.74}'
# b'{"customer_id": 98.0, "order_id": 356.0, "order_amount": 52.15}'
# b'{"customer_id": 93.0, "order_id": 2786.0, "order_amount": 57.02}'
# b'{"customer_id": 92.0, "order_id": 7939.0, "order_amount": 47.05}'
# b'{"customer_id": 28.0, "order_id": 3885.0, "order_amount": 82.62}'
# b'{"customer_id": 25.0, "order_id": 8135.0, "order_amount": 68.0}'
# b'{"customer_id": 40.0, "order_id": 2817.0, "order_amount": 56.17}'
# b'{"customer_id": 73.0, "order_id": 8694.0, "order_amount": 1.54}'
# b'{"customer_id": 68.0, "order_id": 5570.0, "order_amount": 75.22}'
# b'{"customer_id": 83.0, "order_id": 99.0, "order_amount": 81.8}'
# b'{"customer_id": 29.0, "order_id": 9403.0, "order_amount": 51.8}'
# b'{"customer_id": 79.0, "order_id": 3840.0, "order_amount": 82.45}'
# b'{"customer_id": 57.0, "order_id": 3924.0, "order_amount": 63.37}'
# b'{"customer_id": 68.0, "order_id": 3991.0, "order_amount": 72.79}'
# b'{"customer_id": 18.0, "order_id": 7612.0, "order_amount": 11.02}'
# b'{"customer_id": 70.0, "order_id": 8688.0, "order_amount": 87.17}'
# b'{"customer_id": 39.0, "order_id": 802.0, "order_amount": 91.0}'
# b'{"customer_id": 53.0, "order_id": 9241.0, "order_amount": 88.82}'
# b'{"customer_id": 46.0, "order_id": 9324.0, "order_amount": 16.28}'
# b'{"customer_id": 47.0, "order_id": 6633.0, "order_amount": 77.21}'
# b'{"customer_id": 90.0, "order_id": 2733.0, "order_amount": 12.1}'
# b'{"customer_id": 60.0, "order_id": 9143.0, "order_amount": 26.9}'
# b'{"customer_id": 42.0, "order_id": 6476.0, "order_amount": 92.49}'
# b'{"customer_id": 93.0, "order_id": 4904.0, "order_amount": 3.41}'
# b'{"customer_id": 8.0, "order_id": 9293.0, "order_amount": 55.74}'
# b'{"customer_id": 41.0, "order_id": 1041.0, "order_amount": 55.29}'
# b'{"customer_id": 77.0, "order_id": 2604.0, "order_amount": 85.42}'
# b'{"customer_id": 8.0, "order_id": 3444.0, "order_amount": 64.09}'
# b'{"customer_id": 45.0, "order_id": 4722.0, "order_amount": 28.97}'
# b'{"customer_id": 32.0, "order_id": 1399.0, "order_amount": 65.22}'
# b'{"customer_id": 4.0, "order_id": 9242.0, "order_amount": 4.52}'
# b'{"customer_id": 77.0, "order_id": 2534.0, "order_amount": 19.85}'
# b'{"customer_id": 6.0, "order_id": 8756.0, "order_amount": 7.09}'
# b'{"customer_id": 39.0, "order_id": 9419.0, "order_amount": 25.1}'
# b'{"customer_id": 9.0, "order_id": 7235.0, "order_amount": 41.11}'
# b'{"customer_id": 13.0, "order_id": 2038.0, "order_amount": 56.84}'
# b'{"customer_id": 15.0, "order_id": 5529.0, "order_amount": 54.22}'
# b'{"customer_id": 16.0, "order_id": 8993.0, "order_amount": 29.35}'
# b'{"customer_id": 62.0, "order_id": 9517.0, "order_amount": 78.18}'
# b'{"customer_id": 4.0, "order_id": 5824.0, "order_amount": 1.09}'
# b'{"customer_id": 38.0, "order_id": 6126.0, "order_amount": 76.76}'
# b'{"customer_id": 8.0, "order_id": 5544.0, "order_amount": 54.24}'
# b'{"customer_id": 16.0, "order_id": 1370.0, "order_amount": 34.54}'
# b'{"customer_id": 30.0, "order_id": 7481.0, "order_amount": 52.3}'
# b'{"customer_id": 34.0, "order_id": 9090.0, "order_amount": 91.97}'
# b'{"customer_id": 86.0, "order_id": 4751.0, "order_amount": 18.14}'
# b'{"customer_id": 98.0, "order_id": 5049.0, "order_amount": 57.14}'
# b'{"customer_id": 89.0, "order_id": 9733.0, "order_amount": 6.63}'
# b'{"customer_id": 19.0, "order_id": 1376.0, "order_amount": 55.34}'
# b'{"customer_id": 30.0, "order_id": 4527.0, "order_amount": 6.51}'
# b'{"customer_id": 6.0, "order_id": 40.0, "order_amount": 3.53}'
# b'{"customer_id": 84.0, "order_id": 501.0, "order_amount": 67.69}'
# b'{"customer_id": 17.0, "order_id": 8739.0, "order_amount": 77.6}'
# b'{"customer_id": 26.0, "order_id": 2187.0, "order_amount": 40.9}'
# b'{"customer_id": 2.0, "order_id": 8293.0, "order_amount": 17.56}'
# b'{"customer_id": 96.0, "order_id": 5733.0, "order_amount": 32.07}'
# b'{"customer_id": 45.0, "order_id": 5821.0, "order_amount": 21.69}'
# b'{"customer_id": 63.0, "order_id": 4772.0, "order_amount": 84.73}'
# b'{"customer_id": 32.0, "order_id": 3714.0, "order_amount": 20.29}'
# b'{"customer_id": 45.0, "order_id": 2009.0, "order_amount": 1.22}'
# b'{"customer_id": 33.0, "order_id": 91.0, "order_amount": 96.81}'
# b'{"customer_id": 37.0, "order_id": 2653.0, "order_amount": 3.73}'
# b'{"customer_id": 53.0, "order_id": 3277.0, "order_amount": 60.4}'
# b'{"customer_id": 76.0, "order_id": 9697.0, "order_amount": 86.57}'
# b'{"customer_id": 54.0, "order_id": 1239.0, "order_amount": 23.89}'
# b'{"customer_id": 14.0, "order_id": 406.0, "order_amount": 70.65}'
# b'{"customer_id": 90.0, "order_id": 4197.0, "order_amount": 68.75}'
# b'{"customer_id": 83.0, "order_id": 1330.0, "order_amount": 37.89}'
# b'{"customer_id": 27.0, "order_id": 2827.0, "order_amount": 77.07}'
# b'{"customer_id": 26.0, "order_id": 4924.0, "order_amount": 50.75}'
# b'{"customer_id": 4.0, "order_id": 739.0, "order_amount": 49.01}'
# b'{"customer_id": 56.0, "order_id": 8612.0, "order_amount": 0.19}'
# b'{"customer_id": 16.0, "order_id": 1882.0, "order_amount": 89.63}'
# b'{"customer_id": 39.0, "order_id": 1748.0, "order_amount": 33.0}'
# b'{"customer_id": 33.0, "order_id": 2669.0, "order_amount": 69.19}'
# b'{"customer_id": 13.0, "order_id": 6081.0, "order_amount": 16.0}'
# b'{"customer_id": 98.0, "order_id": 7834.0, "order_amount": 75.36}'
# b'{"customer_id": 70.0, "order_id": 5545.0, "order_amount": 68.93}'
# b'{"customer_id": 63.0, "order_id": 1355.0, "order_amount": 46.92}'
# b'{"customer_id": 43.0, "order_id": 4870.0, "order_amount": 67.15}'
# b'{"customer_id": 17.0, "order_id": 1321.0, "order_amount": 82.02}'
# b'{"customer_id": 78.0, "order_id": 5851.0, "order_amount": 47.09}'
# b'{"customer_id": 65.0, "order_id": 7694.0, "order_amount": 46.1}'
# b'{"customer_id": 1.0, "order_id": 9386.0, "order_amount": 58.6}'
# b'{"customer_id": 9.0, "order_id": 3258.0, "order_amount": 96.92}'
# b'{"customer_id": 58.0, "order_id": 3213.0, "order_amount": 21.66}'
# b'{"customer_id": 98.0, "order_id": 7665.0, "order_amount": 62.11}'
# b'{"customer_id": 55.0, "order_id": 8625.0, "order_amount": 74.86}'
# b'{"customer_id": 14.0, "order_id": 8382.0, "order_amount": 38.04}'
# b'{"customer_id": 27.0, "order_id": 9118.0, "order_amount": 97.49}'
# b'{"customer_id": 4.0, "order_id": 7842.0, "order_amount": 22.48}'
# b'{"customer_id": 22.0, "order_id": 3744.0, "order_amount": 6.4}'
# b'{"customer_id": 40.0, "order_id": 6035.0, "order_amount": 0.25}'
# b'{"customer_id": 78.0, "order_id": 3442.0, "order_amount": 71.26}'
# b'{"customer_id": 88.0, "order_id": 6780.0, "order_amount": 58.09}'
# b'{"customer_id": 5.0, "order_id": 5486.0, "order_amount": 23.9}'
# b'{"customer_id": 85.0, "order_id": 1345.0, "order_amount": 13.95}'
# b'{"customer_id": 15.0, "order_id": 6211.0, "order_amount": 33.54}'
# b'{"customer_id": 41.0, "order_id": 8105.0, "order_amount": 74.19}'
# b'{"customer_id": 56.0, "order_id": 8964.0, "order_amount": 77.32}'
# b'{"customer_id": 31.0, "order_id": 5386.0, "order_amount": 42.43}'
# b'{"customer_id": 20.0, "order_id": 3749.0, "order_amount": 93.59}'
# b'{"customer_id": 32.0, "order_id": 2173.0, "order_amount": 90.94}'
# b'{"customer_id": 22.0, "order_id": 4947.0, "order_amount": 43.95}'
# b'{"customer_id": 18.0, "order_id": 8600.0, "order_amount": 97.12}'
# b'{"customer_id": 38.0, "order_id": 6943.0, "order_amount": 29.72}'
# b'{"customer_id": 70.0, "order_id": 8975.0, "order_amount": 44.07}'
# b'{"customer_id": 42.0, "order_id": 2486.0, "order_amount": 18.49}'
# b'{"customer_id": 69.0, "order_id": 1977.0, "order_amount": 71.2}'
# b'{"customer_id": 12.0, "order_id": 2533.0, "order_amount": 98.34}'
# b'{"customer_id": 0.0, "order_id": 7039.0, "order_amount": 90.21}'
# b'{"customer_id": 95.0, "order_id": 2592.0, "order_amount": 84.51}'
# b'{"customer_id": 46.0, "order_id": 7529.0, "order_amount": 46.04}'
# b'{"customer_id": 26.0, "order_id": 9410.0, "order_amount": 13.51}'
# b'{"customer_id": 75.0, "order_id": 628.0, "order_amount": 64.73}'
# b'{"customer_id": 74.0, "order_id": 3808.0, "order_amount": 6.91}'
# b'{"customer_id": 30.0, "order_id": 3837.0, "order_amount": 62.5}'
# b'{"customer_id": 68.0, "order_id": 2180.0, "order_amount": 76.53}'
# b'{"customer_id": 23.0, "order_id": 9510.0, "order_amount": 51.12}'
# b'{"customer_id": 43.0, "order_id": 3321.0, "order_amount": 60.22}'
# b'{"customer_id": 96.0, "order_id": 5915.0, "order_amount": 85.2}'
# b'{"customer_id": 0.0, "order_id": 5126.0, "order_amount": 97.51}'
# b'{"customer_id": 27.0, "order_id": 9245.0, "order_amount": 19.07}'
# b'{"customer_id": 73.0, "order_id": 7703.0, "order_amount": 60.32}'
# b'{"customer_id": 59.0, "order_id": 9241.0, "order_amount": 69.29}'
# b'{"customer_id": 46.0, "order_id": 4038.0, "order_amount": 1.07}'
# b'{"customer_id": 33.0, "order_id": 578.0, "order_amount": 26.4}'
# b'{"customer_id": 16.0, "order_id": 3012.0, "order_amount": 3.58}'
# b'{"customer_id": 61.0, "order_id": 4786.0, "order_amount": 58.09}'
# b'{"customer_id": 43.0, "order_id": 7972.0, "order_amount": 23.35}'
# b'{"customer_id": 34.0, "order_id": 3638.0, "order_amount": 36.82}'
# b'{"customer_id": 59.0, "order_id": 585.0, "order_amount": 83.45}'
# b'{"customer_id": 20.0, "order_id": 9283.0, "order_amount": 84.1}'
# b'{"customer_id": 0.0, "order_id": 6395.0, "order_amount": 15.25}'
# b'{"customer_id": 43.0, "order_id": 3624.0, "order_amount": 56.5}'
# b'{"customer_id": 85.0, "order_id": 6707.0, "order_amount": 84.62}'
# b'{"customer_id": 69.0, "order_id": 2004.0, "order_amount": 58.17}'
# b'{"customer_id": 26.0, "order_id": 565.0, "order_amount": 22.91}'
# b'{"customer_id": 52.0, "order_id": 657.0, "order_amount": 47.59}'
# b'{"customer_id": 10.0, "order_id": 1665.0, "order_amount": 65.31}'
# b'{"customer_id": 6.0, "order_id": 8445.0, "order_amount": 53.89}'
# b'{"customer_id": 87.0, "order_id": 9729.0, "order_amount": 6.7}'
# b'{"customer_id": 66.0, "order_id": 4640.0, "order_amount": 65.45}'
# b'{"customer_id": 95.0, "order_id": 6093.0, "order_amount": 6.17}'
# b'{"customer_id": 15.0, "order_id": 6148.0, "order_amount": 65.53}'
# b'{"customer_id": 44.0, "order_id": 8331.0, "order_amount": 99.19}'
# b'{"customer_id": 5.0, "order_id": 3505.0, "order_amount": 64.18}'
# b'{"customer_id": 48.0, "order_id": 5539.0, "order_amount": 32.42}'
# b'{"customer_id": 47.0, "order_id": 9900.0, "order_amount": 25.66}'
# b'{"customer_id": 31.0, "order_id": 7570.0, "order_amount": 4.16}'
# b'{"customer_id": 4.0, "order_id": 7577.0, "order_amount": 24.13}'
# b'{"customer_id": 36.0, "order_id": 8274.0, "order_amount": 88.64}'
# b'{"customer_id": 57.0, "order_id": 963.0, "order_amount": 57.91}'
# b'{"customer_id": 12.0, "order_id": 4396.0, "order_amount": 72.62}'
# b'{"customer_id": 22.0, "order_id": 7161.0, "order_amount": 56.06}'
# b'{"customer_id": 54.0, "order_id": 7765.0, "order_amount": 28.01}'
# b'{"customer_id": 0.0, "order_id": 3479.0, "order_amount": 97.22}'
# b'{"customer_id": 88.0, "order_id": 1272.0, "order_amount": 80.7}'
# b'{"customer_id": 86.0, "order_id": 9254.0, "order_amount": 71.9}'
# b'{"customer_id": 13.0, "order_id": 4507.0, "order_amount": 26.47}'
# b'{"customer_id": 88.0, "order_id": 1335.0, "order_amount": 29.76}'
# b'{"customer_id": 42.0, "order_id": 6601.0, "order_amount": 22.98}'
# b'{"customer_id": 40.0, "order_id": 3083.0, "order_amount": 72.95}'
# b'{"customer_id": 48.0, "order_id": 6869.0, "order_amount": 27.06}'
# b'{"customer_id": 98.0, "order_id": 30.0, "order_amount": 86.56}'
# b'{"customer_id": 2.0, "order_id": 8212.0, "order_amount": 20.31}'
# b'{"customer_id": 51.0, "order_id": 2187.0, "order_amount": 84.57}'
# b'{"customer_id": 91.0, "order_id": 8363.0, "order_amount": 64.42}'
# b'{"customer_id": 14.0, "order_id": 5388.0, "order_amount": 77.77}'
# b'{"customer_id": 55.0, "order_id": 9904.0, "order_amount": 40.78}'
# b'{"customer_id": 95.0, "order_id": 6984.0, "order_amount": 60.54}'
# b'{"customer_id": 61.0, "order_id": 1696.0, "order_amount": 3.92}'
# b'{"customer_id": 98.0, "order_id": 5352.0, "order_amount": 30.71}'
# b'{"customer_id": 54.0, "order_id": 5658.0, "order_amount": 30.76}'
# b'{"customer_id": 27.0, "order_id": 8517.0, "order_amount": 1.17}'
# b'{"customer_id": 78.0, "order_id": 1085.0, "order_amount": 16.96}'
# b'{"customer_id": 83.0, "order_id": 8384.0, "order_amount": 56.68}'
# b'{"customer_id": 6.0, "order_id": 7808.0, "order_amount": 42.3}'
# b'{"customer_id": 26.0, "order_id": 4990.0, "order_amount": 24.07}'
# b'{"customer_id": 75.0, "order_id": 3585.0, "order_amount": 61.0}'
# b'{"customer_id": 25.0, "order_id": 6268.0, "order_amount": 59.98}'
# b'{"customer_id": 71.0, "order_id": 8232.0, "order_amount": 93.3}'
# b'{"customer_id": 39.0, "order_id": 7744.0, "order_amount": 60.62}'
# b'{"customer_id": 47.0, "order_id": 4653.0, "order_amount": 2.86}'
# b'{"customer_id": 60.0, "order_id": 9604.0, "order_amount": 41.99}'
# b'{"customer_id": 4.0, "order_id": 7236.0, "order_amount": 24.66}'
# b'{"customer_id": 44.0, "order_id": 8602.0, "order_amount": 37.19}'
# b'{"customer_id": 50.0, "order_id": 1506.0, "order_amount": 12.99}'
# b'{"customer_id": 86.0, "order_id": 638.0, "order_amount": 34.38}'
# b'{"customer_id": 97.0, "order_id": 6433.0, "order_amount": 9.35}'
# b'{"customer_id": 7.0, "order_id": 9541.0, "order_amount": 40.34}'
# b'{"customer_id": 21.0, "order_id": 2001.0, "order_amount": 45.77}'
# b'{"customer_id": 75.0, "order_id": 553.0, "order_amount": 56.05}'
# b'{"customer_id": 69.0, "order_id": 9743.0, "order_amount": 0.82}'
# b'{"customer_id": 40.0, "order_id": 7762.0, "order_amount": 85.49}'
# b'{"customer_id": 37.0, "order_id": 8187.0, "order_amount": 91.75}'
# b'{"customer_id": 1.0, "order_id": 6725.0, "order_amount": 9.99}'
# b'{"customer_id": 64.0, "order_id": 3066.0, "order_amount": 52.91}'
# b'{"customer_id": 82.0, "order_id": 5409.0, "order_amount": 87.17}'
# b'{"customer_id": 72.0, "order_id": 3822.0, "order_amount": 30.65}'
# b'{"customer_id": 36.0, "order_id": 7712.0, "order_amount": 53.92}'
# b'{"customer_id": 78.0, "order_id": 1686.0, "order_amount": 19.87}'
# b'{"customer_id": 99.0, "order_id": 4290.0, "order_amount": 17.76}'
# b'{"customer_id": 13.0, "order_id": 1298.0, "order_amount": 10.4}'
# b'{"customer_id": 53.0, "order_id": 4338.0, "order_amount": 68.68}'
# b'{"customer_id": 34.0, "order_id": 4363.0, "order_amount": 51.12}'
# b'{"customer_id": 73.0, "order_id": 4298.0, "order_amount": 60.37}'
# b'{"customer_id": 49.0, "order_id": 8558.0, "order_amount": 36.87}'
# b'{"customer_id": 8.0, "order_id": 2826.0, "order_amount": 9.68}'
# b'{"customer_id": 51.0, "order_id": 8640.0, "order_amount": 66.76}'
# b'{"customer_id": 46.0, "order_id": 6572.0, "order_amount": 23.63}'
# b'{"customer_id": 23.0, "order_id": 8818.0, "order_amount": 6.48}'
# b'{"customer_id": 72.0, "order_id": 4358.0, "order_amount": 48.23}'
# b'{"customer_id": 19.0, "order_id": 8900.0, "order_amount": 80.6}'
# b'{"customer_id": 40.0, "order_id": 4025.0, "order_amount": 18.59}'
# b'{"customer_id": 49.0, "order_id": 6986.0, "order_amount": 29.05}'
# b'{"customer_id": 83.0, "order_id": 827.0, "order_amount": 19.82}'
# b'{"customer_id": 70.0, "order_id": 4491.0, "order_amount": 26.25}'
# b'{"customer_id": 49.0, "order_id": 6866.0, "order_amount": 71.24}'
# b'{"customer_id": 65.0, "order_id": 7938.0, "order_amount": 64.16}'
# b'{"customer_id": 46.0, "order_id": 4967.0, "order_amount": 18.28}'
# b'{"customer_id": 80.0, "order_id": 8540.0, "order_amount": 69.51}'
# b'{"customer_id": 16.0, "order_id": 6626.0, "order_amount": 71.99}'
# b'{"customer_id": 26.0, "order_id": 1922.0, "order_amount": 28.63}'
# b'{"customer_id": 29.0, "order_id": 5853.0, "order_amount": 71.52}'
# b'{"customer_id": 35.0, "order_id": 5368.0, "order_amount": 65.89}'
# b'{"customer_id": 2.0, "order_id": 3391.0, "order_amount": 40.64}'
# b'{"customer_id": 47.0, "order_id": 6694.0, "order_amount": 14.98}'
# b'{"customer_id": 29.0, "order_id": 680.0, "order_amount": 13.08}'
# b'{"customer_id": 91.0, "order_id": 8900.0, "order_amount": 24.59}'
# b'{"customer_id": 70.0, "order_id": 3959.0, "order_amount": 68.68}'
# b'{"customer_id": 85.0, "order_id": 1733.0, "order_amount": 28.53}'
# b'{"customer_id": 53.0, "order_id": 9900.0, "order_amount": 83.55}'
# b'{"customer_id": 14.0, "order_id": 1505.0, "order_amount": 4.32}'
# b'{"customer_id": 51.0, "order_id": 3378.0, "order_amount": 19.8}'
# b'{"customer_id": 42.0, "order_id": 6926.0, "order_amount": 57.77}'
# b'{"customer_id": 2.0, "order_id": 4424.0, "order_amount": 55.77}'
# b'{"customer_id": 79.0, "order_id": 9291.0, "order_amount": 33.17}'
# b'{"customer_id": 50.0, "order_id": 3901.0, "order_amount": 23.57}'
# b'{"customer_id": 20.0, "order_id": 6633.0, "order_amount": 6.49}'
# b'{"customer_id": 9.0, "order_id": 3182.0, "order_amount": 62.76}'
# b'{"customer_id": 86.0, "order_id": 4499.0, "order_amount": 51.49}'
# b'{"customer_id": 6.0, "order_id": 784.0, "order_amount": 51.88}'
# b'{"customer_id": 92.0, "order_id": 5350.0, "order_amount": 18.6}'
# b'{"customer_id": 7.0, "order_id": 5475.0, "order_amount": 80.57}'
# b'{"customer_id": 2.0, "order_id": 6614.0, "order_amount": 21.16}'
# b'{"customer_id": 70.0, "order_id": 9898.0, "order_amount": 24.56}'
# b'{"customer_id": 50.0, "order_id": 4506.0, "order_amount": 23.82}'
# b'{"customer_id": 79.0, "order_id": 574.0, "order_amount": 63.77}'
# b'{"customer_id": 28.0, "order_id": 5548.0, "order_amount": 88.77}'
# b'{"customer_id": 17.0, "order_id": 8236.0, "order_amount": 66.59}'
# b'{"customer_id": 62.0, "order_id": 772.0, "order_amount": 77.8}'
# b'{"customer_id": 58.0, "order_id": 4838.0, "order_amount": 86.77}'
# b'{"customer_id": 68.0, "order_id": 5134.0, "order_amount": 93.76}'
# b'{"customer_id": 18.0, "order_id": 5845.0, "order_amount": 57.29}'
# b'{"customer_id": 79.0, "order_id": 1956.0, "order_amount": 23.55}'
# b'{"customer_id": 2.0, "order_id": 8225.0, "order_amount": 81.96}'
# b'{"customer_id": 57.0, "order_id": 9867.0, "order_amount": 22.36}'
# b'{"customer_id": 79.0, "order_id": 2238.0, "order_amount": 34.72}'
# b'{"customer_id": 80.0, "order_id": 5047.0, "order_amount": 46.66}'
# b'{"customer_id": 64.0, "order_id": 1753.0, "order_amount": 8.55}'
# b'{"customer_id": 27.0, "order_id": 1768.0, "order_amount": 18.78}'
# b'{"customer_id": 62.0, "order_id": 3996.0, "order_amount": 19.49}'
# b'{"customer_id": 93.0, "order_id": 2508.0, "order_amount": 74.65}'
# b'{"customer_id": 73.0, "order_id": 4461.0, "order_amount": 26.4}'
# b'{"customer_id": 59.0, "order_id": 550.0, "order_amount": 25.63}'
# b'{"customer_id": 70.0, "order_id": 2455.0, "order_amount": 38.08}'
# b'{"customer_id": 19.0, "order_id": 3230.0, "order_amount": 44.05}'
# b'{"customer_id": 59.0, "order_id": 1034.0, "order_amount": 83.41}'
# b'{"customer_id": 89.0, "order_id": 4887.0, "order_amount": 50.21}'
# b'{"customer_id": 47.0, "order_id": 7670.0, "order_amount": 38.7}'
# b'{"customer_id": 33.0, "order_id": 9627.0, "order_amount": 97.82}'
# b'{"customer_id": 10.0, "order_id": 1571.0, "order_amount": 11.39}'
# b'{"customer_id": 15.0, "order_id": 7175.0, "order_amount": 83.67}'
# b'{"customer_id": 55.0, "order_id": 3208.0, "order_amount": 7.75}'
# b'{"customer_id": 12.0, "order_id": 2703.0, "order_amount": 76.17}'
# b'{"customer_id": 84.0, "order_id": 2522.0, "order_amount": 62.43}'
# b'{"customer_id": 82.0, "order_id": 8503.0, "order_amount": 94.42}'
# b'{"customer_id": 18.0, "order_id": 1420.0, "order_amount": 8.55}'
# b'{"customer_id": 16.0, "order_id": 474.0, "order_amount": 17.47}'
# b'{"customer_id": 29.0, "order_id": 5802.0, "order_amount": 50.07}'
# b'{"customer_id": 40.0, "order_id": 7019.0, "order_amount": 43.43}'
# b'{"customer_id": 56.0, "order_id": 7182.0, "order_amount": 18.76}'
# b'{"customer_id": 98.0, "order_id": 3218.0, "order_amount": 54.71}'
# b'{"customer_id": 67.0, "order_id": 821.0, "order_amount": 65.83}'
# b'{"customer_id": 90.0, "order_id": 4168.0, "order_amount": 87.47}'
# b'{"customer_id": 21.0, "order_id": 4249.0, "order_amount": 37.58}'
# b'{"customer_id": 41.0, "order_id": 2008.0, "order_amount": 58.25}'
# b'{"customer_id": 79.0, "order_id": 898.0, "order_amount": 36.3}'
# b'{"customer_id": 27.0, "order_id": 607.0, "order_amount": 99.63}'
# b'{"customer_id": 69.0, "order_id": 712.0, "order_amount": 1.35}'
# b'{"customer_id": 90.0, "order_id": 6452.0, "order_amount": 16.99}'
# b'{"customer_id": 90.0, "order_id": 6978.0, "order_amount": 98.36}'
# b'{"customer_id": 39.0, "order_id": 4171.0, "order_amount": 88.6}'
# b'{"customer_id": 53.0, "order_id": 6741.0, "order_amount": 8.22}'
# b'{"customer_id": 43.0, "order_id": 1524.0, "order_amount": 13.35}'
# b'{"customer_id": 37.0, "order_id": 53.0, "order_amount": 51.14}'
# b'{"customer_id": 84.0, "order_id": 8220.0, "order_amount": 65.29}'
# b'{"customer_id": 90.0, "order_id": 6995.0, "order_amount": 52.29}'
# b'{"customer_id": 45.0, "order_id": 6832.0, "order_amount": 28.6}'
# b'{"customer_id": 89.0, "order_id": 5030.0, "order_amount": 29.2}'
# b'{"customer_id": 52.0, "order_id": 6122.0, "order_amount": 79.5}'
# b'{"customer_id": 55.0, "order_id": 8991.0, "order_amount": 57.13}'
# b'{"customer_id": 74.0, "order_id": 3491.0, "order_amount": 49.88}'
# b'{"customer_id": 20.0, "order_id": 7308.0, "order_amount": 41.22}'
# b'{"customer_id": 15.0, "order_id": 4015.0, "order_amount": 49.45}'
# b'{"customer_id": 44.0, "order_id": 2232.0, "order_amount": 59.9}'
# b'{"customer_id": 26.0, "order_id": 4417.0, "order_amount": 41.6}'
# b'{"customer_id": 81.0, "order_id": 7872.0, "order_amount": 77.16}'
# b'{"customer_id": 5.0, "order_id": 8233.0, "order_amount": 76.63}'
# b'{"customer_id": 37.0, "order_id": 529.0, "order_amount": 81.75}'
# b'{"customer_id": 35.0, "order_id": 276.0, "order_amount": 11.03}'
# b'{"customer_id": 73.0, "order_id": 7130.0, "order_amount": 63.05}'
# b'{"customer_id": 42.0, "order_id": 9963.0, "order_amount": 80.36}'
# b'{"customer_id": 12.0, "order_id": 4076.0, "order_amount": 50.9}'
# b'{"customer_id": 18.0, "order_id": 6719.0, "order_amount": 38.46}'
# b'{"customer_id": 63.0, "order_id": 2361.0, "order_amount": 60.1}'
# b'{"customer_id": 99.0, "order_id": 2804.0, "order_amount": 92.87}'
# b'{"customer_id": 67.0, "order_id": 6966.0, "order_amount": 64.26}'
# b'{"customer_id": 22.0, "order_id": 915.0, "order_amount": 72.12}'
# b'{"customer_id": 56.0, "order_id": 8208.0, "order_amount": 22.42}'
# b'{"customer_id": 8.0, "order_id": 2407.0, "order_amount": 60.03}'
# b'{"customer_id": 48.0, "order_id": 9724.0, "order_amount": 27.94}'
# b'{"customer_id": 76.0, "order_id": 3875.0, "order_amount": 53.85}'
# b'{"customer_id": 51.0, "order_id": 8382.0, "order_amount": 32.7}'
# b'{"customer_id": 50.0, "order_id": 5461.0, "order_amount": 11.59}'
# b'{"customer_id": 42.0, "order_id": 9226.0, "order_amount": 27.06}'
# b'{"customer_id": 58.0, "order_id": 8806.0, "order_amount": 40.74}'
# b'{"customer_id": 17.0, "order_id": 2162.0, "order_amount": 50.17}'
# b'{"customer_id": 51.0, "order_id": 8298.0, "order_amount": 3.08}'
# b'{"customer_id": 72.0, "order_id": 1590.0, "order_amount": 96.39}'
# b'{"customer_id": 3.0, "order_id": 8382.0, "order_amount": 38.24}'
# b'{"customer_id": 5.0, "order_id": 7530.0, "order_amount": 38.84}'
# b'{"customer_id": 26.0, "order_id": 6358.0, "order_amount": 87.36}'
# b'{"customer_id": 79.0, "order_id": 6918.0, "order_amount": 48.69}'
# b'{"customer_id": 27.0, "order_id": 9718.0, "order_amount": 6.61}'
# b'{"customer_id": 89.0, "order_id": 5120.0, "order_amount": 76.72}'
# b'{"customer_id": 40.0, "order_id": 9704.0, "order_amount": 63.37}'
# b'{"customer_id": 58.0, "order_id": 7424.0, "order_amount": 24.85}'
# b'{"customer_id": 43.0, "order_id": 761.0, "order_amount": 95.62}'
# b'{"customer_id": 95.0, "order_id": 8686.0, "order_amount": 83.76}'
# b'{"customer_id": 61.0, "order_id": 5905.0, "order_amount": 66.27}'
# b'{"customer_id": 83.0, "order_id": 1350.0, "order_amount": 6.53}'
# b'{"customer_id": 63.0, "order_id": 4957.0, "order_amount": 61.11}'
# b'{"customer_id": 96.0, "order_id": 8722.0, "order_amount": 90.56}'
# b'{"customer_id": 7.0, "order_id": 5289.0, "order_amount": 29.81}'
# b'{"customer_id": 67.0, "order_id": 6181.0, "order_amount": 35.02}'
# b'{"customer_id": 46.0, "order_id": 1526.0, "order_amount": 73.07}'
# b'{"customer_id": 73.0, "order_id": 2966.0, "order_amount": 31.04}'
# b'{"customer_id": 76.0, "order_id": 8784.0, "order_amount": 75.54}'
# b'{"customer_id": 29.0, "order_id": 9505.0, "order_amount": 40.81}'
# b'{"customer_id": 39.0, "order_id": 1627.0, "order_amount": 12.55}'
# b'{"customer_id": 29.0, "order_id": 9114.0, "order_amount": 70.19}'
# b'{"customer_id": 9.0, "order_id": 8212.0, "order_amount": 35.41}'
# b'{"customer_id": 50.0, "order_id": 1041.0, "order_amount": 69.24}'
# b'{"customer_id": 47.0, "order_id": 5734.0, "order_amount": 69.02}'
# b'{"customer_id": 29.0, "order_id": 3206.0, "order_amount": 0.4}'
# b'{"customer_id": 86.0, "order_id": 91.0, "order_amount": 14.74}'
# b'{"customer_id": 86.0, "order_id": 6717.0, "order_amount": 2.12}'
# b'{"customer_id": 78.0, "order_id": 4273.0, "order_amount": 23.06}'
# b'{"customer_id": 27.0, "order_id": 5894.0, "order_amount": 59.48}'
# b'{"customer_id": 86.0, "order_id": 9625.0, "order_amount": 18.87}'
# b'{"customer_id": 12.0, "order_id": 7368.0, "order_amount": 90.54}'
# b'{"customer_id": 81.0, "order_id": 5844.0, "order_amount": 3.96}'
# b'{"customer_id": 33.0, "order_id": 3027.0, "order_amount": 3.06}'
# b'{"customer_id": 81.0, "order_id": 2128.0, "order_amount": 71.96}'
# b'{"customer_id": 60.0, "order_id": 1145.0, "order_amount": 52.74}'
# b'{"customer_id": 52.0, "order_id": 6234.0, "order_amount": 34.15}'
# b'{"customer_id": 39.0, "order_id": 127.0, "order_amount": 89.47}'
# b'{"customer_id": 25.0, "order_id": 8142.0, "order_amount": 48.44}'
# b'{"customer_id": 71.0, "order_id": 2678.0, "order_amount": 24.04}'
# b'{"customer_id": 12.0, "order_id": 1076.0, "order_amount": 70.27}'
# b'{"customer_id": 1.0, "order_id": 9194.0, "order_amount": 95.9}'
# b'{"customer_id": 10.0, "order_id": 9184.0, "order_amount": 52.2}'
# b'{"customer_id": 16.0, "order_id": 5987.0, "order_amount": 18.26}'
# b'{"customer_id": 25.0, "order_id": 2108.0, "order_amount": 36.8}'
# b'{"customer_id": 49.0, "order_id": 7353.0, "order_amount": 13.58}'
# b'{"customer_id": 42.0, "order_id": 498.0, "order_amount": 23.92}'
# b'{"customer_id": 16.0, "order_id": 5613.0, "order_amount": 50.1}'
# b'{"customer_id": 81.0, "order_id": 1716.0, "order_amount": 39.92}'
# b'{"customer_id": 91.0, "order_id": 1907.0, "order_amount": 24.06}'
# b'{"customer_id": 41.0, "order_id": 1258.0, "order_amount": 39.99}'
# b'{"customer_id": 73.0, "order_id": 8478.0, "order_amount": 9.53}'
# b'{"customer_id": 54.0, "order_id": 5644.0, "order_amount": 95.03}'
# b'{"customer_id": 34.0, "order_id": 6842.0, "order_amount": 36.36}'
# b'{"customer_id": 53.0, "order_id": 9341.0, "order_amount": 48.86}'
# b'{"customer_id": 48.0, "order_id": 1676.0, "order_amount": 82.57}'
# b'{"customer_id": 14.0, "order_id": 4270.0, "order_amount": 61.82}'
# b'{"customer_id": 50.0, "order_id": 2883.0, "order_amount": 5.5}'
# b'{"customer_id": 6.0, "order_id": 3687.0, "order_amount": 43.72}'
# b'{"customer_id": 89.0, "order_id": 1255.0, "order_amount": 43.18}'
# b'{"customer_id": 79.0, "order_id": 4052.0, "order_amount": 92.46}'
# b'{"customer_id": 60.0, "order_id": 8108.0, "order_amount": 31.57}'
# b'{"customer_id": 42.0, "order_id": 3362.0, "order_amount": 72.51}'
# b'{"customer_id": 46.0, "order_id": 8513.0, "order_amount": 25.7}'
# b'{"customer_id": 94.0, "order_id": 5284.0, "order_amount": 39.92}'
# b'{"customer_id": 18.0, "order_id": 4328.0, "order_amount": 70.77}'
# b'{"customer_id": 43.0, "order_id": 3205.0, "order_amount": 58.77}'
# b'{"customer_id": 81.0, "order_id": 5125.0, "order_amount": 62.56}'
# b'{"customer_id": 42.0, "order_id": 4337.0, "order_amount": 87.39}'
# b'{"customer_id": 15.0, "order_id": 6790.0, "order_amount": 59.47}'
# b'{"customer_id": 76.0, "order_id": 4415.0, "order_amount": 84.08}'
# b'{"customer_id": 99.0, "order_id": 8913.0, "order_amount": 98.12}'
# b'{"customer_id": 28.0, "order_id": 3354.0, "order_amount": 84.11}'
# b'{"customer_id": 33.0, "order_id": 9390.0, "order_amount": 66.67}'
# b'{"customer_id": 67.0, "order_id": 6460.0, "order_amount": 28.06}'
# b'{"customer_id": 48.0, "order_id": 708.0, "order_amount": 8.73}'
# b'{"customer_id": 61.0, "order_id": 6001.0, "order_amount": 2.82}'
# b'{"customer_id": 21.0, "order_id": 112.0, "order_amount": 92.98}'
# b'{"customer_id": 31.0, "order_id": 6961.0, "order_amount": 35.42}'
# b'{"customer_id": 8.0, "order_id": 345.0, "order_amount": 27.53}'
# b'{"customer_id": 85.0, "order_id": 6313.0, "order_amount": 67.07}'
# b'{"customer_id": 31.0, "order_id": 4724.0, "order_amount": 9.34}'
# b'{"customer_id": 40.0, "order_id": 8839.0, "order_amount": 28.72}'
# b'{"customer_id": 53.0, "order_id": 8348.0, "order_amount": 9.09}'
# b'{"customer_id": 10.0, "order_id": 8064.0, "order_amount": 0.15}'
# b'{"customer_id": 54.0, "order_id": 9202.0, "order_amount": 54.76}'
# b'{"customer_id": 26.0, "order_id": 8737.0, "order_amount": 5.75}'
# b'{"customer_id": 60.0, "order_id": 36.0, "order_amount": 72.87}'
# b'{"customer_id": 72.0, "order_id": 6927.0, "order_amount": 13.43}'
# b'{"customer_id": 89.0, "order_id": 3690.0, "order_amount": 82.31}'
# b'{"customer_id": 45.0, "order_id": 5969.0, "order_amount": 21.19}'
# b'{"customer_id": 29.0, "order_id": 3381.0, "order_amount": 82.05}'
# b'{"customer_id": 83.0, "order_id": 2955.0, "order_amount": 53.8}'
# b'{"customer_id": 83.0, "order_id": 3730.0, "order_amount": 61.26}'
# b'{"customer_id": 73.0, "order_id": 9962.0, "order_amount": 42.09}'
# b'{"customer_id": 54.0, "order_id": 1606.0, "order_amount": 0.26}'
# b'{"customer_id": 21.0, "order_id": 7735.0, "order_amount": 73.26}'
# b'{"customer_id": 88.0, "order_id": 2675.0, "order_amount": 10.64}'
# b'{"customer_id": 75.0, "order_id": 6264.0, "order_amount": 83.77}'
# b'{"customer_id": 60.0, "order_id": 662.0, "order_amount": 2.95}'
# b'{"customer_id": 39.0, "order_id": 587.0, "order_amount": 49.09}'
# b'{"customer_id": 34.0, "order_id": 8833.0, "order_amount": 22.88}'
# b'{"customer_id": 35.0, "order_id": 4331.0, "order_amount": 20.14}'
# b'{"customer_id": 68.0, "order_id": 5459.0, "order_amount": 38.82}'
# b'{"customer_id": 20.0, "order_id": 1230.0, "order_amount": 85.0}'
# b'{"customer_id": 39.0, "order_id": 6769.0, "order_amount": 44.17}'
# b'{"customer_id": 19.0, "order_id": 2226.0, "order_amount": 63.14}'
# b'{"customer_id": 81.0, "order_id": 5290.0, "order_amount": 80.37}'
# b'{"customer_id": 34.0, "order_id": 4148.0, "order_amount": 90.42}'
# b'{"customer_id": 37.0, "order_id": 3655.0, "order_amount": 65.12}'
# b'{"customer_id": 78.0, "order_id": 8795.0, "order_amount": 13.4}'
# b'{"customer_id": 46.0, "order_id": 2484.0, "order_amount": 71.3}'
# b'{"customer_id": 33.0, "order_id": 3254.0, "order_amount": 83.9}'
# b'{"customer_id": 27.0, "order_id": 4040.0, "order_amount": 86.57}'
# b'{"customer_id": 47.0, "order_id": 831.0, "order_amount": 88.37}'
# b'{"customer_id": 84.0, "order_id": 5928.0, "order_amount": 99.17}'
# b'{"customer_id": 8.0, "order_id": 1349.0, "order_amount": 32.61}'
# b'{"customer_id": 79.0, "order_id": 1058.0, "order_amount": 55.25}'
# b'{"customer_id": 50.0, "order_id": 8397.0, "order_amount": 20.56}'
# b'{"customer_id": 99.0, "order_id": 3225.0, "order_amount": 48.78}'
# b'{"customer_id": 47.0, "order_id": 8688.0, "order_amount": 74.29}'
# b'{"customer_id": 94.0, "order_id": 2423.0, "order_amount": 82.21}'
# b'{"customer_id": 56.0, "order_id": 9862.0, "order_amount": 75.79}'
# b'{"customer_id": 46.0, "order_id": 5099.0, "order_amount": 15.22}'
# b'{"customer_id": 66.0, "order_id": 5900.0, "order_amount": 0.17}'
# b'{"customer_id": 58.0, "order_id": 1057.0, "order_amount": 24.65}'
# b'{"customer_id": 93.0, "order_id": 6822.0, "order_amount": 63.24}'
# ...
# b'{"customer_id": 96.0, "order_id": 7080.0, "order_amount": 46.05}'
# b'{"customer_id": 64.0, "order_id": 2602.0, "order_amount": 1.94}'
# b'{"customer_id": 76.0, "order_id": 5923.0, "order_amount": 5.39}'
# b'{"customer_id": 17.0, "order_id": 5670.0, "order_amount": 99.25}'
# b'{"customer_id": 67.0, "order_id": 4895.0, "order_amount": 88.13}'
# b'{"customer_id": 71.0, "order_id": 6956.0, "order_amount": 82.51}'
# b'{"customer_id": 9.0, "order_id": 2139.0, "order_amount": 86.21}'
# b'{"customer_id": 30.0, "order_id": 7396.0, "order_amount": 43.82}'
# b'{"customer_id": 64.0, "order_id": 1747.0, "order_amount": 99.2}'
# b'{"customer_id": 55.0, "order_id": 8315.0, "order_amount": 80.97}'
# b'{"customer_id": 68.0, "order_id": 1346.0, "order_amount": 20.25}'
# b'{"customer_id": 9.0, "order_id": 8058.0, "order_amount": 38.61}'
# b'{"customer_id": 90.0, "order_id": 6170.0, "order_amount": 52.23}'
# b'{"customer_id": 5.0, "order_id": 2259.0, "order_amount": 10.06}'
# b'{"customer_id": 31.0, "order_id": 3256.0, "order_amount": 54.91}'
# b'{"customer_id": 40.0, "order_id": 424.0, "order_amount": 90.66}'
# b'{"customer_id": 3.0, "order_id": 4904.0, "order_amount": 14.16}'
# b'{"customer_id": 1.0, "order_id": 1785.0, "order_amount": 18.34}'
# b'{"customer_id": 74.0, "order_id": 9613.0, "order_amount": 7.89}'
# b'{"customer_id": 42.0, "order_id": 9046.0, "order_amount": 68.93}'
# b'{"customer_id": 37.0, "order_id": 102.0, "order_amount": 52.52}'
# b'{"customer_id": 90.0, "order_id": 7702.0, "order_amount": 33.57}'
# b'{"customer_id": 58.0, "order_id": 6647.0, "order_amount": 66.1}'
# b'{"customer_id": 45.0, "order_id": 2120.0, "order_amount": 84.76}'
# b'{"customer_id": 49.0, "order_id": 9689.0, "order_amount": 46.39}'
# b'{"customer_id": 11.0, "order_id": 4032.0, "order_amount": 57.12}'
# b'{"customer_id": 73.0, "order_id": 6431.0, "order_amount": 31.99}'
# b'{"customer_id": 74.0, "order_id": 8424.0, "order_amount": 3.25}'
# b'{"customer_id": 24.0, "order_id": 3527.0, "order_amount": 38.42}'
# b'{"customer_id": 2.0, "order_id": 9112.0, "order_amount": 66.16}'
# b'{"customer_id": 10.0, "order_id": 2759.0, "order_amount": 54.62}'
# b'{"customer_id": 57.0, "order_id": 7521.0, "order_amount": 64.99}'
# b'{"customer_id": 54.0, "order_id": 8638.0, "order_amount": 48.86}'
# b'{"customer_id": 49.0, "order_id": 7898.0, "order_amount": 4.8}'
# b'{"customer_id": 95.0, "order_id": 6996.0, "order_amount": 56.47}'
# b'{"customer_id": 65.0, "order_id": 1569.0, "order_amount": 71.9}'
# b'{"customer_id": 86.0, "order_id": 6065.0, "order_amount": 70.1}'
# b'{"customer_id": 3.0, "order_id": 9954.0, "order_amount": 78.49}'
# b'{"customer_id": 75.0, "order_id": 9119.0, "order_amount": 84.26}'
# b'{"customer_id": 79.0, "order_id": 4332.0, "order_amount": 72.15}'
# b'{"customer_id": 61.0, "order_id": 5969.0, "order_amount": 96.28}'
# b'{"customer_id": 57.0, "order_id": 470.0, "order_amount": 49.41}'
# b'{"customer_id": 16.0, "order_id": 2623.0, "order_amount": 42.96}'
# b'{"customer_id": 66.0, "order_id": 7187.0, "order_amount": 69.22}'
# b'{"customer_id": 12.0, "order_id": 390.0, "order_amount": 94.77}'
# b'{"customer_id": 41.0, "order_id": 4323.0, "order_amount": 59.98}'
# b'{"customer_id": 70.0, "order_id": 7384.0, "order_amount": 62.86}'
# b'{"customer_id": 36.0, "order_id": 2731.0, "order_amount": 22.7}'
# b'{"customer_id": 46.0, "order_id": 7505.0, "order_amount": 58.64}'
# b'{"customer_id": 42.0, "order_id": 5842.0, "order_amount": 18.15}'
# b'{"customer_id": 44.0, "order_id": 6262.0, "order_amount": 2.66}'
# b'{"customer_id": 17.0, "order_id": 5060.0, "order_amount": 99.71}'
# b'{"customer_id": 25.0, "order_id": 9205.0, "order_amount": 27.63}'
# b'{"customer_id": 17.0, "order_id": 3729.0, "order_amount": 56.9}'
# b'{"customer_id": 42.0, "order_id": 3476.0, "order_amount": 95.39}'
# b'{"customer_id": 38.0, "order_id": 92.0, "order_amount": 8.76}'
# b'{"customer_id": 26.0, "order_id": 3820.0, "order_amount": 83.17}'
# b'{"customer_id": 39.0, "order_id": 6772.0, "order_amount": 83.27}'
# b'{"customer_id": 12.0, "order_id": 8745.0, "order_amount": 38.75}'
# b'{"customer_id": 71.0, "order_id": 8379.0, "order_amount": 0.54}'
# b'{"customer_id": 49.0, "order_id": 7520.0, "order_amount": 45.58}'
# b'{"customer_id": 98.0, "order_id": 9307.0, "order_amount": 58.46}'
# b'{"customer_id": 56.0, "order_id": 2602.0, "order_amount": 64.23}'
# b'{"customer_id": 51.0, "order_id": 1100.0, "order_amount": 91.47}'
# b'{"customer_id": 5.0, "order_id": 7735.0, "order_amount": 79.0}'
# b'{"customer_id": 11.0, "order_id": 7373.0, "order_amount": 48.83}'
# b'{"customer_id": 81.0, "order_id": 6598.0, "order_amount": 49.86}'
# b'{"customer_id": 74.0, "order_id": 9201.0, "order_amount": 44.66}'
# b'{"customer_id": 65.0, "order_id": 1836.0, "order_amount": 39.17}'
# b'{"customer_id": 25.0, "order_id": 3813.0, "order_amount": 68.65}'
# b'{"customer_id": 68.0, "order_id": 7842.0, "order_amount": 46.88}'
# b'{"customer_id": 14.0, "order_id": 8178.0, "order_amount": 39.91}'
# b'{"customer_id": 9.0, "order_id": 9168.0, "order_amount": 29.46}'
# b'{"customer_id": 29.0, "order_id": 9907.0, "order_amount": 45.34}'
# b'{"customer_id": 15.0, "order_id": 1001.0, "order_amount": 86.43}'
# b'{"customer_id": 62.0, "order_id": 3410.0, "order_amount": 11.65}'
# b'{"customer_id": 68.0, "order_id": 1300.0, "order_amount": 83.85}'
# b'{"customer_id": 24.0, "order_id": 7603.0, "order_amount": 60.84}'
# b'{"customer_id": 47.0, "order_id": 5962.0, "order_amount": 18.72}'
# b'{"customer_id": 23.0, "order_id": 8372.0, "order_amount": 92.91}'
# b'{"customer_id": 57.0, "order_id": 5983.0, "order_amount": 68.88}'
# b'{"customer_id": 95.0, "order_id": 2594.0, "order_amount": 92.19}'
# b'{"customer_id": 53.0, "order_id": 6410.0, "order_amount": 72.61}'
# b'{"customer_id": 92.0, "order_id": 5627.0, "order_amount": 79.48}'
# b'{"customer_id": 6.0, "order_id": 1132.0, "order_amount": 14.78}'
# b'{"customer_id": 72.0, "order_id": 6073.0, "order_amount": 55.7}'
# b'{"customer_id": 41.0, "order_id": 167.0, "order_amount": 56.16}'
# b'{"customer_id": 6.0, "order_id": 156.0, "order_amount": 98.51}'
# b'{"customer_id": 84.0, "order_id": 1453.0, "order_amount": 62.96}'
# b'{"customer_id": 75.0, "order_id": 1783.0, "order_amount": 6.38}'
# b'{"customer_id": 40.0, "order_id": 5031.0, "order_amount": 21.53}'
# b'{"customer_id": 40.0, "order_id": 6825.0, "order_amount": 79.79}'
# b'{"customer_id": 10.0, "order_id": 8054.0, "order_amount": 46.56}'
# b'{"customer_id": 63.0, "order_id": 3082.0, "order_amount": 49.48}'
# b'{"customer_id": 23.0, "order_id": 6148.0, "order_amount": 4.98}'
# b'{"customer_id": 37.0, "order_id": 9677.0, "order_amount": 37.41}'
# b'{"customer_id": 66.0, "order_id": 7183.0, "order_amount": 24.79}'
# b'{"customer_id": 98.0, "order_id": 2373.0, "order_amount": 62.16}'
# b'{"customer_id": 65.0, "order_id": 3213.0, "order_amount": 15.65}'
# b'{"customer_id": 62.0, "order_id": 9691.0, "order_amount": 17.51}'
# b'{"customer_id": 22.0, "order_id": 8816.0, "order_amount": 62.03}'
# b'{"customer_id": 33.0, "order_id": 8616.0, "order_amount": 35.7}'
# b'{"customer_id": 36.0, "order_id": 4201.0, "order_amount": 79.6}'
# b'{"customer_id": 0.0, "order_id": 8495.0, "order_amount": 34.28}'
# b'{"customer_id": 85.0, "order_id": 566.0, "order_amount": 79.15}'
# b'{"customer_id": 65.0, "order_id": 1331.0, "order_amount": 74.8}'
# b'{"customer_id": 84.0, "order_id": 7331.0, "order_amount": 91.2}'
# b'{"customer_id": 59.0, "order_id": 4649.0, "order_amount": 58.67}'
# b'{"customer_id": 60.0, "order_id": 2007.0, "order_amount": 10.45}'
# b'{"customer_id": 15.0, "order_id": 3621.0, "order_amount": 54.16}'
# b'{"customer_id": 71.0, "order_id": 3400.0, "order_amount": 35.07}'
# b'{"customer_id": 54.0, "order_id": 6094.0, "order_amount": 39.92}'
# b'{"customer_id": 84.0, "order_id": 3792.0, "order_amount": 56.64}'
# b'{"customer_id": 25.0, "order_id": 8405.0, "order_amount": 51.44}'
# b'{"customer_id": 71.0, "order_id": 9173.0, "order_amount": 70.38}'
# b'{"customer_id": 73.0, "order_id": 8014.0, "order_amount": 7.96}'
# b'{"customer_id": 69.0, "order_id": 7209.0, "order_amount": 13.13}'
# b'{"customer_id": 65.0, "order_id": 3273.0, "order_amount": 61.29}'
# b'{"customer_id": 3.0, "order_id": 1548.0, "order_amount": 63.92}'
# b'{"customer_id": 38.0, "order_id": 2777.0, "order_amount": 25.0}'
# b'{"customer_id": 5.0, "order_id": 488.0, "order_amount": 9.2}'
# b'{"customer_id": 0.0, "order_id": 2062.0, "order_amount": 43.61}'
# b'{"customer_id": 36.0, "order_id": 5173.0, "order_amount": 69.68}'
# b'{"customer_id": 34.0, "order_id": 7485.0, "order_amount": 67.39}'
# b'{"customer_id": 69.0, "order_id": 3666.0, "order_amount": 74.91}'
# b'{"customer_id": 3.0, "order_id": 1329.0, "order_amount": 86.47}'
# b'{"customer_id": 27.0, "order_id": 306.0, "order_amount": 44.97}'
# b'{"customer_id": 93.0, "order_id": 2685.0, "order_amount": 93.71}'
# b'{"customer_id": 72.0, "order_id": 7656.0, "order_amount": 54.94}'
# b'{"customer_id": 75.0, "order_id": 6973.0, "order_amount": 0.7}'
# b'{"customer_id": 47.0, "order_id": 2737.0, "order_amount": 30.04}'
# b'{"customer_id": 29.0, "order_id": 7139.0, "order_amount": 48.85}'
# b'{"customer_id": 91.0, "order_id": 4081.0, "order_amount": 91.41}'
# b'{"customer_id": 14.0, "order_id": 5323.0, "order_amount": 77.43}'
# b'{"customer_id": 65.0, "order_id": 3087.0, "order_amount": 71.11}'
# b'{"customer_id": 1.0, "order_id": 40.0, "order_amount": 25.6}'
# b'{"customer_id": 84.0, "order_id": 431.0, "order_amount": 74.14}'
# b'{"customer_id": 13.0, "order_id": 9550.0, "order_amount": 52.27}'
# b'{"customer_id": 14.0, "order_id": 3159.0, "order_amount": 52.04}'
# b'{"customer_id": 73.0, "order_id": 5220.0, "order_amount": 80.57}'
# b'{"customer_id": 41.0, "order_id": 4310.0, "order_amount": 93.71}'
# b'{"customer_id": 8.0, "order_id": 8249.0, "order_amount": 77.15}'
# b'{"customer_id": 64.0, "order_id": 6862.0, "order_amount": 45.8}'
# b'{"customer_id": 78.0, "order_id": 1481.0, "order_amount": 82.3}'
# b'{"customer_id": 29.0, "order_id": 9095.0, "order_amount": 32.26}'
# b'{"customer_id": 58.0, "order_id": 671.0, "order_amount": 84.4}'
# b'{"customer_id": 76.0, "order_id": 2435.0, "order_amount": 37.95}'
# b'{"customer_id": 44.0, "order_id": 6380.0, "order_amount": 97.08}'
# b'{"customer_id": 12.0, "order_id": 1717.0, "order_amount": 8.12}'
# b'{"customer_id": 46.0, "order_id": 7255.0, "order_amount": 59.44}'
# b'{"customer_id": 51.0, "order_id": 1463.0, "order_amount": 68.42}'
# b'{"customer_id": 12.0, "order_id": 1881.0, "order_amount": 65.94}'
# b'{"customer_id": 92.0, "order_id": 2122.0, "order_amount": 22.3}'
# b'{"customer_id": 27.0, "order_id": 4539.0, "order_amount": 42.06}'
# b'{"customer_id": 36.0, "order_id": 255.0, "order_amount": 17.58}'
# b'{"customer_id": 81.0, "order_id": 3602.0, "order_amount": 50.11}'
# b'{"customer_id": 90.0, "order_id": 1129.0, "order_amount": 86.66}'
# b'{"customer_id": 40.0, "order_id": 1554.0, "order_amount": 34.43}'
# b'{"customer_id": 58.0, "order_id": 6701.0, "order_amount": 9.14}'
# b'{"customer_id": 33.0, "order_id": 2277.0, "order_amount": 18.57}'
# b'{"customer_id": 37.0, "order_id": 657.0, "order_amount": 32.92}'
# b'{"customer_id": 60.0, "order_id": 5477.0, "order_amount": 15.54}'
# b'{"customer_id": 33.0, "order_id": 7892.0, "order_amount": 0.54}'
# b'{"customer_id": 54.0, "order_id": 2518.0, "order_amount": 46.7}'
# b'{"customer_id": 5.0, "order_id": 5382.0, "order_amount": 40.89}'
# b'{"customer_id": 17.0, "order_id": 6837.0, "order_amount": 2.62}'
# b'{"customer_id": 26.0, "order_id": 4745.0, "order_amount": 35.39}'
# b'{"customer_id": 89.0, "order_id": 2686.0, "order_amount": 25.84}'
# b'{"customer_id": 86.0, "order_id": 7431.0, "order_amount": 98.3}'
# b'{"customer_id": 47.0, "order_id": 189.0, "order_amount": 7.77}'
# b'{"customer_id": 52.0, "order_id": 5117.0, "order_amount": 38.53}'
# b'{"customer_id": 0.0, "order_id": 2969.0, "order_amount": 88.66}'
# b'{"customer_id": 35.0, "order_id": 5551.0, "order_amount": 78.21}'
# b'{"customer_id": 41.0, "order_id": 9207.0, "order_amount": 30.87}'
# b'{"customer_id": 40.0, "order_id": 8984.0, "order_amount": 59.97}'
# b'{"customer_id": 47.0, "order_id": 819.0, "order_amount": 52.94}'
# b'{"customer_id": 59.0, "order_id": 8329.0, "order_amount": 58.56}'
# b'{"customer_id": 97.0, "order_id": 9955.0, "order_amount": 77.74}'
# b'{"customer_id": 92.0, "order_id": 457.0, "order_amount": 96.17}'
# b'{"customer_id": 60.0, "order_id": 1367.0, "order_amount": 51.97}'
# b'{"customer_id": 43.0, "order_id": 7330.0, "order_amount": 73.28}'
# b'{"customer_id": 78.0, "order_id": 4261.0, "order_amount": 83.52}'
# b'{"customer_id": 59.0, "order_id": 7993.0, "order_amount": 39.96}'
# b'{"customer_id": 28.0, "order_id": 4444.0, "order_amount": 24.91}'
# b'{"customer_id": 91.0, "order_id": 9998.0, "order_amount": 76.0}'
# b'{"customer_id": 9.0, "order_id": 8622.0, "order_amount": 91.61}'
# b'{"customer_id": 97.0, "order_id": 570.0, "order_amount": 8.24}'
# b'{"customer_id": 69.0, "order_id": 2444.0, "order_amount": 27.12}'
# b'{"customer_id": 12.0, "order_id": 7336.0, "order_amount": 87.21}'
# b'{"customer_id": 71.0, "order_id": 4945.0, "order_amount": 48.7}'
# b'{"customer_id": 23.0, "order_id": 6494.0, "order_amount": 75.04}'
# b'{"customer_id": 52.0, "order_id": 6781.0, "order_amount": 22.55}'
# b'{"customer_id": 63.0, "order_id": 8395.0, "order_amount": 77.97}'
# b'{"customer_id": 54.0, "order_id": 7488.0, "order_amount": 8.14}'
# b'{"customer_id": 90.0, "order_id": 1930.0, "order_amount": 25.34}'
# b'{"customer_id": 9.0, "order_id": 8960.0, "order_amount": 19.87}'
# b'{"customer_id": 8.0, "order_id": 9012.0, "order_amount": 65.84}'
# b'{"customer_id": 58.0, "order_id": 1460.0, "order_amount": 2.37}'
# b'{"customer_id": 18.0, "order_id": 2506.0, "order_amount": 16.34}'
# b'{"customer_id": 97.0, "order_id": 9635.0, "order_amount": 0.4}'
# b'{"customer_id": 55.0, "order_id": 8859.0, "order_amount": 2.02}'
# b'{"customer_id": 27.0, "order_id": 790.0, "order_amount": 29.12}'
# b'{"customer_id": 74.0, "order_id": 4648.0, "order_amount": 99.34}'
# b'{"customer_id": 68.0, "order_id": 8242.0, "order_amount": 84.21}'
# b'{"customer_id": 1.0, "order_id": 8388.0, "order_amount": 49.56}'
# b'{"customer_id": 21.0, "order_id": 2249.0, "order_amount": 98.21}'
# b'{"customer_id": 68.0, "order_id": 8521.0, "order_amount": 93.62}'
# b'{"customer_id": 8.0, "order_id": 9790.0, "order_amount": 15.28}'
# b'{"customer_id": 45.0, "order_id": 9570.0, "order_amount": 52.86}'
# b'{"customer_id": 62.0, "order_id": 9668.0, "order_amount": 84.25}'
# b'{"customer_id": 5.0, "order_id": 9990.0, "order_amount": 0.46}'
# b'{"customer_id": 19.0, "order_id": 5733.0, "order_amount": 70.53}'
# b'{"customer_id": 22.0, "order_id": 6164.0, "order_amount": 61.0}'
# b'{"customer_id": 64.0, "order_id": 7678.0, "order_amount": 81.81}'
# b'{"customer_id": 21.0, "order_id": 1697.0, "order_amount": 74.68}'
# b'{"customer_id": 54.0, "order_id": 5587.0, "order_amount": 12.52}'
# b'{"customer_id": 36.0, "order_id": 2140.0, "order_amount": 1.23}'
# b'{"customer_id": 66.0, "order_id": 8278.0, "order_amount": 20.92}'
# b'{"customer_id": 83.0, "order_id": 3167.0, "order_amount": 17.18}'
# b'{"customer_id": 58.0, "order_id": 5760.0, "order_amount": 62.3}'
# b'{"customer_id": 66.0, "order_id": 7381.0, "order_amount": 80.27}'
# b'{"customer_id": 34.0, "order_id": 6402.0, "order_amount": 82.7}'
# b'{"customer_id": 95.0, "order_id": 6259.0, "order_amount": 96.74}'
# b'{"customer_id": 92.0, "order_id": 941.0, "order_amount": 66.52}'
# b'{"customer_id": 54.0, "order_id": 2961.0, "order_amount": 86.76}'
# b'{"customer_id": 67.0, "order_id": 7993.0, "order_amount": 87.88}'
# b'{"customer_id": 38.0, "order_id": 1476.0, "order_amount": 6.91}'
# b'{"customer_id": 43.0, "order_id": 8711.0, "order_amount": 90.12}'
# b'{"customer_id": 67.0, "order_id": 2842.0, "order_amount": 7.1}'
# b'{"customer_id": 15.0, "order_id": 9260.0, "order_amount": 37.39}'
# b'{"customer_id": 68.0, "order_id": 9076.0, "order_amount": 66.47}'
# b'{"customer_id": 51.0, "order_id": 8586.0, "order_amount": 21.18}'
# b'{"customer_id": 21.0, "order_id": 8623.0, "order_amount": 76.84}'
# b'{"customer_id": 6.0, "order_id": 9160.0, "order_amount": 84.98}'
# b'{"customer_id": 67.0, "order_id": 6696.0, "order_amount": 78.09}'
# b'{"customer_id": 72.0, "order_id": 8760.0, "order_amount": 41.57}'

# %%
pipeline.cancel()
# Out:
# 'CANCELLING'
